# %% [markdown]
# <a href="https://colab.research.google.com/github/aarchi-dot/deep-learning/blob/main/lab-assignmnet-3-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
